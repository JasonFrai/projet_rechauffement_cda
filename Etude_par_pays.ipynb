# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
#Attention, pas encore terminé. Besoin d'organiser les différentes analyses.

# %%
df_global = pd.read_csv(r"C:\Users\jason\Documents\Project rechauffement\ZonAnn.Ts+dSST.csv",index_col=0)
df_global.head()
# Out:
#       Glob  NHem  SHem  24N-90N  24S-24N  90S-24S  64N-90N  44N-64N  24N-44N  \
# Year
# 1880 -0.17 -0.28 -0.05    -0.37    -0.13    -0.02    -0.81    -0.46    -0.28
# 1881 -0.09 -0.18  0.00    -0.34     0.10    -0.07    -0.90    -0.43    -0.21
# 1882 -0.11 -0.21 -0.01    -0.31    -0.05     0.01    -1.40    -0.25    -0.16
# 1883 -0.18 -0.29 -0.07    -0.35    -0.17    -0.02    -0.19    -0.54    -0.28
# 1884 -0.28 -0.42 -0.15    -0.60    -0.15    -0.14    -1.29    -0.62    -0.47
#
#       EQU-24N  24S-EQU  44S-24S  64S-44S  90S-64S
# Year
# 1880    -0.16    -0.11    -0.05     0.05     0.66
# 1881     0.09     0.10    -0.06    -0.07     0.58
# 1882    -0.06    -0.05     0.00     0.04     0.61
# 1883    -0.18    -0.15    -0.05     0.07     0.49
# 1884    -0.13    -0.16    -0.20    -0.02     0.64

# %%
temp_pays = pd.read_csv(r"C:\Users\jason\Documents\Project rechauffement\Annual_Surface_Temperature_Change.csv",index_col=1)
temp_pays.columns
temp_pays.head()
# Out:
#                               ObjectId ISO2 ISO3  \
# Country
# Afghanistan, Islamic Rep. of         1   AF  AFG
# Albania                              2   AL  ALB
# Algeria                              3   DZ  DZA
# American Samoa                       4   AS  ASM
# Andorra, Principality of             5   AD  AND
#
#                                                                       Indicator  \
# Country
# Afghanistan, Islamic Rep. of  Temperature change with respect to a baseline ...
# Albania                       Temperature change with respect to a baseline ...
# Algeria                       Temperature change with respect to a baseline ...
# American Samoa                Temperature change with respect to a baseline ...
# Andorra, Principality of      Temperature change with respect to a baseline ...
#
#                                         Unit  \
# Country
# Afghanistan, Islamic Rep. of  Degree Celsius
# Albania                       Degree Celsius
# ...

# %%
temp_pays2 = temp_pays.drop(temp_pays.columns[0:9], axis=1)
Rename = {'F1961':'1961','F1962': '1962', 'F1963':'1963', 'F1964':'1964','F1965': '1965', 'F1966':'1966', 'F1967':'1967','F1968': '1968',
       'F1969':'1969', 'F1970':'1970', 'F1971':'1971','F1972': '1972', 'F1973':'1973','F1974': '1974', 'F1975':'1975', 'F1976':'1976',
       'F1977':'1977','F1978': '1978','F1979': '1979','F1980': '1980','F1981': '1981','F1982': '1982', 'F1983':'1983','F1984': '1984',
       'F1985':'1985', 'F1986':'1986', 'F1987':'1987', 'F1988':'1988','F1989': '1989','F1990': '1990', 'F1991':'1991','F1992': '1992',
       'F1993':'1993','F1994': '1994','F1995': '1995','F1996': '1996','F1997': '1997','F1998': '1998','F1999': '1999','F2000': '2000',
       'F2001':'2001','F2002': '2002','F2003': '2003','F2004': '2004','F2005': '2005','F2006': '2006','F2007': '2007','F2008': '2008',
       'F2009':'2009','F2010': '2010','F2011': '2011','F2012': '2012','F2013': '2013','F2014': '2014','F2015': '2015','F2016': '2016',
       'F2017':'2017','F2018': '2018','F2019': '2019','F2020': '2020','F2021': '2021','F2022': '2022'}
temp_pays2.rename(Rename,axis=1,inplace=True)
temp_pays2.head()
# Out:
#                                1961   1962   1963   1964   1965   1966   1967  \
# Country
# Afghanistan, Islamic Rep. of -0.113 -0.164  0.847 -0.764 -0.244  0.226 -0.371
# Albania                       0.627  0.326  0.075 -0.166 -0.388  0.559 -0.074
# Algeria                       0.164  0.114  0.077  0.250 -0.100  0.433 -0.026
# American Samoa                0.079 -0.042  0.169 -0.140 -0.562  0.181 -0.368
# Andorra, Principality of      0.736  0.112 -0.752  0.308 -0.490  0.415  0.637
#
#                                1968   1969   1970  ...   2013   2014   2015  \
# Country                                            ...
# Afghanistan, Islamic Rep. of -0.423 -0.539  0.813  ...  1.281  0.456  1.093
# Albania                       0.081 -0.013 -0.106  ...  1.333  1.198  1.569
# Algeria                      -0.067  0.291  0.116  ...  1.192  1.690  1.121
# American Samoa               -0.187  0.132 -0.047  ...  1.257  1.170  1.009
# ...

# %%
temp_pays3 = temp_pays2.T
temp_pays3.head()
# Out:
# Country  Afghanistan, Islamic Rep. of  Albania  Algeria  American Samoa  \
# 1961                           -0.113    0.627    0.164           0.079
# 1962                           -0.164    0.326    0.114          -0.042
# 1963                            0.847    0.075    0.077           0.169
# 1964                           -0.764   -0.166    0.250          -0.140
# 1965                           -0.244   -0.388   -0.100          -0.562
#
# Country  Andorra, Principality of  Angola  Anguilla  Antigua and Barbuda  \
# 1961                        0.736   0.041     0.086                0.090
# 1962                        0.112  -0.152    -0.024                0.031
# 1963                       -0.752  -0.190     0.234                0.288
# 1964                        0.308  -0.229     0.189                0.214
# 1965                       -0.490  -0.196    -0.365               -0.385
#
# Country  Argentina  Armenia, Rep. of  ...  Vanuatu  \
# ...

# %%
hdi_pays=pd.read_csv(r"C:\Users\jason\Documents\Project rechauffement\HDR21-22.csv",index_col=1)
hdi_pays.head()
hdi_pays2 = hdi_pays[['hdi_1990','hdi_1991','hdi_1992','hdi_1993','hdi_1994','hdi_1995','hdi_1996','hdi_1997','hdi_1998','hdi_1999','hdi_2000','hdi_2001','hdi_2002','hdi_2003','hdi_2004','hdi_2005','hdi_2006','hdi_2007','hdi_2008','hdi_2009','hdi_2010','hdi_2011','hdi_2012','hdi_2013','hdi_2014','hdi_2015','hdi_2016','hdi_2017','hdi_2018','hdi_2019','hdi_2020','hdi_2021']]
Rename2 = {'hdi_1990':'1990','hdi_1991':'1991','hdi_1992':'1992','hdi_1993':'1993','hdi_1994':'1994','hdi_1995':'1995','hdi_1996':'1996','hdi_1997':'1997','hdi_1998':"1998",'hdi_1999':'1999','hdi_2000':'2000','hdi_2001':'2001','hdi_2002':'2002','hdi_2003':'2003','hdi_2004':'2004','hdi_2005':'2005','hdi_2006':'2006','hdi_2007':'2007','hdi_2008':'2008','hdi_2009':'2009','hdi_2010':'2010','hdi_2011':"2011",'hdi_2012':"2012",'hdi_2013':"2013",'hdi_2014':"2014",'hdi_2015':'2015','hdi_2016':'2016','hdi_2017':'2017','hdi_2018':'2018','hdi_2019':'2019','hdi_2020':"2020",'hdi_2021':'2021'}
hdi_pays2.rename(Rename2,axis=1,inplace=True)
hdi_pays3 = hdi_pays.T
# Out:
# C:\Users\jason\AppData\Local\Temp\ipykernel_9952\424692806.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hdi_pays2.rename(Rename2,axis=1,inplace=True)

# %%
hdi_pays3 = hdi_pays2.T
hdi_pays3
# Out:
# country  Afghanistan  Angola  Albania  Andorra  United Arab Emirates  \
# 1990           0.273     NaN    0.647      NaN                 0.728
# 1991           0.279     NaN    0.629      NaN                 0.739
# 1992           0.287     NaN    0.614      NaN                 0.742
# 1993           0.297     NaN    0.617      NaN                 0.748
# 1994           0.292     NaN    0.624      NaN                 0.755
# 1995           0.310     NaN    0.634      NaN                 0.762
# 1996           0.319     NaN    0.645      NaN                 0.767
# 1997           0.323     NaN    0.642      NaN                 0.773
# 1998           0.324     NaN    0.657      NaN                 0.779
# 1999           0.332   0.364    0.669      NaN                 0.787
# 2000           0.335   0.375    0.677    0.818                 0.796
# 2001           0.337   0.386    0.684    0.825                 0.800
# 2002           0.362   0.403    0.689    0.832                 0.804
# ...

# %%
plt.plot(range(1990,2022),hdi_pays3['Austria'])
plt.plot(range(1960,2022),temp_pays3['Austria'])
plt.plot(range(1999,2022),indus_pays2['Austria']);

# %%
indus_pays = pd.read_csv(r"C:\Users\jason\Documents\Project rechauffement\Industriel.csv",index_col=1)

indus_pays.drop("Indicator",axis=1,inplace = True)
indus_pays2=indus_pays.T

# %%
plt.plot(range(1999,2022),indus_pays2['Austria'])

# %%
indus_pays2["Austria"]=indus_pays2['Austria'].astype('float')

# %%
indus_pays2
# Out:
# Country Albania Andorra Armenia  Austria Azerbaijan Belarus Belgium  \
# 2000       12.0      ..     6.4      8.7        6.9     7.5      ..
# 2001      -20.0      ..     5.3      3.1        5.1     5.9     4.5
# 2002       11.0      ..    14.6      1.0        3.6     4.0     0.3
# 2003        8.0      ..    15.1      1.8        6.1     6.7     1.6
# 2004        2.0      ..     2.1      7.1        5.7    15.3     7.1
# 2005       -0.2      ..     7.5      3.9       33.5    10.0     3.3
# 2006       10.6      ..    -0.9      7.1       36.6    11.2     6.1
# 2007       11.4      ..     2.6      5.9       24.0     8.6     7.9
# 2008       16.8      ..     2.0      2.2        6.0    11.3     4.1
# 2009        7.2      ..    -7.8    -11.8        8.6    -3.1   -11.2
# 2010       37.5      ..     9.7      7.0        2.6    11.7     9.4
# 2011       27.1      ..    14.1      6.3       -5.0     9.1     4.6
# 2012       12.9      ..     8.8     -0.1       -2.3     5.8    -1.7
# ...

# %%
cata_nat = pd.read_csv(r"C:\Users\jason\Documents\Project rechauffement\pend-gdis-1960-2018-disasterlocations.csv")
#Source = SEDAC
cata_nat.sort_values(by="year",ascending = True,inplace = True)
#cata_nat["id"].unique().shape
#cata_nat = cata_nat.set_index("year")
cata_nat
# Out:
#            id      country iso3   gwno  year  geo_id          geolocation  \
# 11905    1080        Chile  CHL  155.0  1960    3744         Puerto Montt
# 36265  04-378        Italy  ITA  325.0  1960   39480      Laveno-Mombello
# 24537    4939  Philippines  PHL  840.0  1960   17740  Metropolitan Manila
# 24536    4936  Philippines  PHL  840.0  1960   17739  Metropolitan Manila
# 10686     112      Algeria  DZA  220.0  1960     537               M'Sila
# ...       ...          ...  ...    ...   ...     ...                  ...
# 31043  02-142        China  CHN  710.0  2018   30865               Fujian
# 31044  02-142        China  CHN  710.0  2018   30866              Sichuan
# 31045  02-142        China  CHN  710.0  2018   30867                Henan
# 31037  02-141        China  CHN  710.0  2018   30859             Zhejiang
# 7159   02-168         Cuba  CUB   40.0  2018   31010              Sandino
#
#        level                 adm1        adm2             adm3  \
# ...

# %%
#Suppression doublon
cata_nat2 = cata_nat.drop_duplicates(subset = "id")
#24N-90N	24S-24N	90S-24S	64N-90N	44N-64N	24N-44N	EQU-24N	24S-EQU	44S-24S	64S-44S	90S-64S
cata_nat2[cata_nat2["latitude"]<-44]
# Out:
#             id      country iso3   gwno  year  geo_id  \
# 17096     4506  New Zealand  NZL  920.0  1968   14438
# 29031  01-1038  New Zealand  NEW  920.0  1978   28108
# 36332   04-483  New Zealand  NEW  920.0  1979   39724
# 26845     4512  New Zealand  NZL  920.0  1980   14471
# 26846     4513  New Zealand  NZL  920.0  1980   14459
# 26847     4516  New Zealand  NZL  920.0  1984   14472
# 17107     4520  New Zealand  NZL  920.0  1986   14483
# 17109     4523  New Zealand  NZL  920.0  1987   14443
# 28951     1094        Chile  CHL  155.0  1990    3749
# 17116     4530  New Zealand  NZL  920.0  1991   14432
# 36770   19-May    Argentina  ARG  160.0  1991   40496
# 26854     4539  New Zealand  NZL  920.0  1999   14461
# 28871     4548  New Zealand  NZL  920.0  2006   14433
# 33719   21-Mar    Argentina  ARG  160.0  2007   35851
# 24393     1119        Chile  CHL  155.0  2007    3657
# 33219   03-113        Chile  CHL  155.0  2010   35195
# ...

# %%
import seaborn as sns

# %%
sns.displot(cata_nat2[cata_nat2["latitude"]<-44].year)
sns.displot(cata_nat2[(cata_nat2["latitude"]>-44) & (cata_nat2["latitude"]<-24)].year);

# %%
#Suite = Reste à comparer la monter des catastrophes naturelles avec la monter des température, en fonction des latitude
